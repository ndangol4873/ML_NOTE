# %%
import numpy as np
import pandas as pd
from flask import Flask, jsonify, request

# %%
# ipl_matches = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRy2DUdUbaKx_Co9F0FSnIlyS-8kp4aKv_I0-qzNeghiZHAI_hw94gKG22XTxNJHMFnFVKsO4xWOdIs/pub?gid=1655759976&single=true&output=csv"
# matches = pd.read_csv(ipl_matches)

# %%
matches = pd.read_csv('d:/ML_NOTE_DATASET/ipl-matches.csv')

# %%
matches.shape
# Out:
# (950, 20)

# %%
valid_team = list(set(list(matches['Team1']) + list(matches['Team2'])))

# %%
team1 = 'Rajasthan Royals'
team2 = 'Royal Challengers Bangalore'

# %%
temp_df = matches.loc[(matches['Team1'] == team1) & (matches['Team2'] == team2) | (matches['Team1'] == team2) & (matches['Team2'] == team1)]
temp_df.head(2)
# Out:
#          ID       City        Date Season  MatchNumber  \
# 1   1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 35  1304085       Pune  2022-04-26   2022           39
#
#                           Team1                        Team2  \
# 1   Royal Challengers Bangalore             Rajasthan Royals
# 35             Rajasthan Royals  Royal Challengers Bangalore
#
#                                             Venue  \
# 1                Narendra Modi Stadium, Ahmedabad
# 35  Maharashtra Cricket Association Stadium, Pune
#
#                      TossWinner TossDecision SuperOver       WinningTeam  \
# 1              Rajasthan Royals        field         N  Rajasthan Royals
# 35  Royal Challengers Bangalore        field         N  Rajasthan Royals
#
#       WonBy  Margin method Player_of_Match  \
# 1   Wickets     7.0    NaN      JC Buttler
# 35     Runs    29.0    NaN         R Parag
#
#                                          Team1Players  \
# ...

# %%
matches[(matches['Team1'] == team1) | (matches['Team2'] == team1)]
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 1    1312199  Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198    Kolkata  2022-05-25     2022   Eliminator
# 7    1304113     Mumbai  2022-05-19     2022           67
# 14   1304106     Mumbai  2022-05-13     2022           60
# 20   1304100     Mumbai  2022-05-08     2022           54
# ..       ...        ...         ...      ...          ...
# 933   335998      Delhi  2008-04-30  2007/08           17
# 935   335996  Bangalore  2008-04-28  2007/08           15
# 939   335992  Bangalore  2008-04-26  2007/08           12
# 946   335985     Mumbai  2008-04-20  2007/08            5
# 949   335982  Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 7                 Gujarat Titans  Royal Challengers Bangalore
# ...

# %%
total_matches = temp_df.shape[0]

# %%
matches_won_team1 = temp_df['WinningTeam'].value_counts()[team1]
matches_won_team2 = temp_df['WinningTeam'].value_counts()[team2]
matches_won_draw = total_matches - (matches_won_team1 + matches_won_team2)
matches_won_draw
# Out:
# np.int64(2)

# %%
def teamVteamAPI(team1,team2):
    valid_team = list(set(list(matches['Team1']) + list(matches['Team2'])))

    if team1 in valid_team and team2 in valid_team:
        temp_df = matches.loc[(matches['Team1'] == team1) & (matches['Team2'] == team2) | (matches['Team1'] == team2) & (matches['Team2'] == team1)]
        total_matches = temp_df.shape[0]

        matches_won_team1 = temp_df['WinningTeam'].value_counts()[team1]
        matches_won_team2 = temp_df['WinningTeam'].value_counts()[team2]

        draws = total_matches - (matches_won_team1 + matches_won_team2)

        response = {
            'total_matches': str(total_matches),
              team1: str(matches_won_team1),
              team2: str(matches_won_team2),
              'draws': str(draws)
        }

        return response
    else:
        return {'message' : 'Invalid Team Name'}

    



teamVteamAPI(team1, team2)
# Out:
# {'total_matches': '27',
#  'Rajasthan Royals': '12',
#  'Royal Challengers Bangalore': '13',
#  'draws': '2'}

# %%
# ipl_ball = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRu6cb6Pj8C9elJc5ubswjVTObommsITlNsFy5X0EiBY7S-lsHEUqx3g_M16r50Ytjc0XQCdGDyzE_Y/pub?output=csv"
# balls = pd.read_csv(ipl_ball)
# balls.head()

# %%
import os
from pathlib import Path
Path(os.getcwd())
# Out:
# WindowsPath('d:/ML_NOTE/Python/API/Flask_API_campusx')

# %%
balls = pd.read_csv('d:/ML_NOTE_DATASET/IPL_Ball_by_Ball_2008_2022.csv')
balls.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
balls.shape
# Out:
# (225954, 17)

# %%
pd.set_option('display.max_column', None)

# %%
ball_withmatch = balls.merge(matches, on='ID', how='inner').copy()
# ball_withmatch['BowlingTeam'] = ball_withmatch.Team1 + ball_withmatch.Team2
# ball_withmatch['BowlingTeam'] = ball_withmatch[['BowlingTeam', 'BattingTeam']]
# ball_withmatch['BowlingTeam'] = ball_withmatch[['BowlingTeam', 'BattingTeam']].apply(lambda x: x.values[0].replace(x.values[1], ''), axis=1)
# batter_data = ball_withmatch[np.append(balls.columns.values, ['BowlingTeam', 'Player_of_Match'])]

print(ball_withmatch.shape)
ball_withmatch.head(2)
# Out:
# (225954, 36)
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
#
#   non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0  JC Buttler        NaN            0           0          0             0
# 1  JC Buttler    legbyes            0           1          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam  \
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
#
#         City        Date Season MatchNumber             Team1           Team2  \
# 0  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals  Gujarat Titans
# 1  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals  Gujarat Titans
#
# ...

# %%
valid_team = list(set(list(matches['Team1']) + list(matches['Team2'])))
valid_team
# Out:
# ['Punjab Kings',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Kochi Tuskers Kerala',
#  'Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Rising Pune Supergiant',
#  'Gujarat Lions',
#  'Deccan Chargers',
#  'Delhi Daredevils',
#  'Kings XI Punjab',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Gujarat Titans',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Pune Warriors']

# %%
ball_withmatch['Team1']
# Out:
# 0                    Rajasthan Royals
# 1                    Rajasthan Royals
# 2                    Rajasthan Royals
# 3                    Rajasthan Royals
# 4                    Rajasthan Royals
#                      ...
# 225949    Royal Challengers Bangalore
# 225950    Royal Challengers Bangalore
# 225951    Royal Challengers Bangalore
# 225952    Royal Challengers Bangalore
# 225953    Royal Challengers Bangalore
# Name: Team1, Length: 225954, dtype: object

# %%
ball_withmatch['Team2']
# Out:
# 0                Gujarat Titans
# 1                Gujarat Titans
# 2                Gujarat Titans
# 3                Gujarat Titans
# 4                Gujarat Titans
#                   ...
# 225949    Kolkata Knight Riders
# 225950    Kolkata Knight Riders
# 225951    Kolkata Knight Riders
# 225952    Kolkata Knight Riders
# 225953    Kolkata Knight Riders
# Name: Team2, Length: 225954, dtype: object

# %%
ball_withmatch['BattingTeam']
# Out:
# 0                    Rajasthan Royals
# 1                    Rajasthan Royals
# 2                    Rajasthan Royals
# 3                    Rajasthan Royals
# 4                    Rajasthan Royals
#                      ...
# 225949    Royal Challengers Bangalore
# 225950    Royal Challengers Bangalore
# 225951    Royal Challengers Bangalore
# 225952    Royal Challengers Bangalore
# 225953    Royal Challengers Bangalore
# Name: BattingTeam, Length: 225954, dtype: object

# %%
None if ball_withmatch['Team1'] in ball_withmatch['BattingTeam'].values else ball_withmatch['Team1']

# %%
bowling_team = []
for index, (team1, battingteam) in enumerate(zip(ball_withmatch['Team1'], ball_withmatch['BattingTeam'])):
    if team1 == battingteam:
        bowling_team.append(np.nan)
    else:
        bowling_team.append(team1)

ball_withmatch['BowlingTeam'] = bowling_team
ball_withmatch['BowlingTeam'] = ball_withmatch['BowlingTeam'].fillna(ball_withmatch['Team2'])
batter_data = ball_withmatch[['BowlingTeam','BattingTeam','Player_of_Match']]

# %%
batter_data = ball_withmatch[['BowlingTeam','BattingTeam','Player_of_Match']]
